# %% [markdown]
# Санкт-Петербургский Государственный Политехнический Университет
# ## Дисциплина: Вычислительная математика
# # **Лабораторная работа №3**

# %% [markdown]
# ## Формулировка задания
# ![Формулировка задания](./meta/3.jpg)

# %% [markdown]
# ## Теоретический материал
# Система ОДУ задана функцией system(t, y), которая описывает изменения переменных x1 и x2 во времени.
# **Метод Рунге-Кутты-Фельберга (RK45)** — адаптивный метод 5-го порядка с автоматическим выбором шага. Решается с помощью solve_ivp из scipy.integrate.
# **Метод Рунге-Кутты 4-го порядка (RK4)** — явный метод с фиксированным шагом интегрирования. Реализован вручную через функцию runge_kutta, используя классическую формулу.

# %% [markdown]
# ## Результаты работы программы

# %%
import importlib
importlib.reload(main)
# Out:
# Сравнение значений x1 и x2:
# t        x1 (III)     x1 (IVa)     x1 (IVб)     x2 (III)     x2 (IVa)     x2 (IVб)
# 0.00     0.000000     0.000000     0.000000     1.000000     1.000000     1.000000
# 0.02     -8.591667    10.868884    -8.559541    0.865187     0.800319     0.865080
# 0.04     -7.226876    29.613881    -7.226598    0.726118     0.603316     0.726118
# 0.06     -6.082401    63.570167    -6.081975    0.611498     0.379323     0.611497
# 0.08     -5.137447    126.547964   -5.138126    0.516985     0.078034     0.516987
# 0.10     -4.358633    244.609854   -4.359166    0.438967     -0.390928    0.438969
# 0.12     -3.715156    466.991612   -3.715448    0.374477     -1.194545    0.374478
# 0.14     -3.182714    886.747855   -3.182687    0.321086     -2.645349    0.321086
# 0.16     -2.741143    1679.783946  -2.740991    0.276804     -5.331613    0.276803
# 0.18     -2.374220    3178.649648  -2.374067    0.240002     -10.363410   0.240002
# ...

# %% [markdown]
# ## Вывод
# Вычислим критический шаг:
# ![Критический шаг](./meta/1.png)
# Значение z:
# ![Значение z](./meta/2.png)
# В таблице вывода видно, что второй столбец содержит совсем не те значения, которые мы ожидаем увидеть. Это связано с тем, что шаг, данный в задании, незначительно, но все-таки больше критического, из-за чего и получаются неправильные результаты.
